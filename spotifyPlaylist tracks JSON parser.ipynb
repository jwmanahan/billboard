# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import json

# %%
# Last run Nov 28, 2022
# May be missing tracks in playlist not owned by Spotify
start = 0
increment = 100 # Max limit allowed

while start <= 1603: # 1603 is current number of tracks
    print(
        f"""
        curl -o number_one_country_{start}.json -X "GET" "https://api.spotify.com/v1/playlists/2USBpRPrBS3sKOzcucReSh/tracks?offset={start}&limit=100&market=US" -H "Accept: application/json" -H "Content-Type: application/json" -H "Authorization: Bearer BQC3jC0GfAihqZEE0YOnNjYEYSVMBg8MuOmGPUFF-g6263ZMTAGKj8z3RcHTx1cGkBP83bIvpjU03zvWEB_GezkpCRZcNCiBLSdEcTWdZzhvEm_t3srSVvsuG9343xvvuZq-khHDsfLLiNlWlJ8L7I7Rawggd1ef6azE6ssLWtXsCN7rlYZ2VlD5UjvM1R7y-3c"
        """
    )
    start += increment
# Out:
#         curl -o number_one_country_0.json -X "GET" "https://api.spotify.com/v1/playlists/2USBpRPrBS3sKOzcucReSh/tracks?offset=0&limit=100&market=US" -H "Accept: application/json" -H "Content-Type: application/json" -H "Authorization: Bearer BQC3jC0GfAihqZEE0YOnNjYEYSVMBg8MuOmGPUFF-g6263ZMTAGKj8z3RcHTx1cGkBP83bIvpjU03zvWEB_GezkpCRZcNCiBLSdEcTWdZzhvEm_t3srSVvsuG9343xvvuZq-khHDsfLLiNlWlJ8L7I7Rawggd1ef6azE6ssLWtXsCN7rlYZ2VlD5UjvM1R7y-3c"
#
#
#         curl -o number_one_country_100.json -X "GET" "https://api.spotify.com/v1/playlists/2USBpRPrBS3sKOzcucReSh/tracks?offset=100&limit=100&market=US" -H "Accept: application/json" -H "Content-Type: application/json" -H "Authorization: Bearer BQC3jC0GfAihqZEE0YOnNjYEYSVMBg8MuOmGPUFF-g6263ZMTAGKj8z3RcHTx1cGkBP83bIvpjU03zvWEB_GezkpCRZcNCiBLSdEcTWdZzhvEm_t3srSVvsuG9343xvvuZq-khHDsfLLiNlWlJ8L7I7Rawggd1ef6azE6ssLWtXsCN7rlYZ2VlD5UjvM1R7y-3c"
#
#
# ...

# %%
def pp(content, indent = 4):
    print(json.dumps(content, indent = indent))

# %%
artist_to_tracks = {}
artist_to_albums_of_tracks = {}

ix = 0 # Must be start plus any number of increments
if (ix - start) % increment !=0:
    raise Exception("Please change ix to a number in the title of a json file")
    # Or comment the line above out

while ix <= 1603: # 1603 is max track number
    with open(f'spotify/number_one_country_{ix}.json') as json_file:
        jo = json.load(json_file)

    for i in jo['items']:
        track = i['track']
        album_name = track['album']['name']
        album_year = track['album']['release_date']
                      
        for artist in track['artists']:
            artist_name = artist['name']
            
            if artist_name not in artist_to_tracks.keys():
                artist_to_tracks[artist_name] = [track['name']] # Assumed never null
                artist_to_albums_of_tracks[artist_name] = {album_name : album_year}
            else:
                artist_to_tracks[artist_name] += [track['name']]
                if track_album_name not in artist_to_albums_of_tracks.keys():
                    artist_to_albums_of_tracks[artist_name][album_name] = album_year
                
    ix += 100

print(ix)
# Out:
# 1700

# %%
# Fix a mistaken double entry
artist_to_tracks['The Karaoke Channel'].pop(
    artist_to_tracks['The Karaoke Channel'].index(
        'Easy Loving [In the Style of Freddie Hart] {Karaoke Lead Vocal Version}'
    )
)
# Out:
# 'Easy Loving [In the Style of Freddie Hart] {Karaoke Lead Vocal Version}'

# %%
# Rectify obvious mis-attributions
pp(artist_to_tracks)
# Out:
# {
#     "Morgan Wallen": [
#         "You Proof",
#         "Wasted On You",
#         "Thought You Should Know",
#         "Don't Think Jesus",
#         "7 Summers",
#         "Whiskey Glasses"
#     ],
#     "Luke Combs": [
#         "The Kind of Love We Make",
#         "Forever After All",
#         "Better Together",
#         "Beautiful Crazy",
#         "When It Rains It Pours"
#     ],
#     "Cody Johnson": [
#         "'Til You Can't"
#     ],
#     "Jordan Davis": [
#         "Buy Dirt"
#     ],
#     "Luke Bryan": [
#         "Buy Dirt",
#         "Strip It Down",
#         "Kick The Dust Up",
#         "I See You",
#         "Play It Again",
#         "This Is How We Roll",
#         "Drink A Beer",
#         "That's My Kind Of Night",
#         "Drunk On You",
#         "I Don't Want This Night To End",
#         "Someone Else Calling You Baby",
#         "Rain Is A Good Thing"
#     ],
#     "Chris Stapleton": [
#         "You Should Probably Leave",
# ...

# %% [markdown]
# - Billboard Hot Country 100 started in 1958
# - Must be listed as an artist.  Featured counts!
# - Razzy Bailey probably has too many in this list
# - Clint Eastwood is missing.  Should have Bar Room Buddies.
# - Name anyone in a duet, or name the duet.  Your choice

# %%
spotify_artist_to_preferred_artist = {
    'Anita Cochran with Steve Wariner' : 'Anita Cochran' # Wariner already has it
    , 'The Sounds Of Garth Brooks' : 'Garth Brooks'
    , '#1 Garth Brooks Tribute Band' : 'Garth Brooks'
    , 'Emmylou Harris, Dolly Parton & Linda Ronstadt' : 'Emmylou Harris' # Others already have it
    , 'Janie Frickie' : 'Janie Fricke' # Assumed to be alternate spellings
    , 'The Statlers' : 'The Statler Brothers' # Alternate name
    , 'Merle Haggard & The Strangers' : 'Merle Haggard' # Design decision that these are the same
    , 'Jack Blanchard & Misty Morgan' : 'Jack Blanchard' # Morgan already has it
    , 'Joe Stampley & The Uniques' : 'Joe Stampley' # Design decision that these are the same
}

ignorable_artists = [
    'The Strangers'
    , 'The Buckaroos'
]

track_to_preferred_artist = {
    'Somewhere Tonight - Single (In the Style of Highway 101) [Performance Track with Demonstration Vocals]' : 'Highway 101'
    , 'My Hang-Up Is You - Single (In the Style of Freddie Hart) [Performance Track with Demonstration Vocals]' : 'Freddie Hart'
    , "100% Chance Of Rain (Made Popular By Gary Morris) [Vocal Version]" : 'Gary Morris'
    , "Bar Room Buddies (In the Style of Merle Haggard & Clint Eastwood) [Karaoke Version]" : 'Merle Haggard'
    , "Heart Healer (In the Style of Mel Tillis) [Karaoke Version]" : 'Mel Tillis'
    , "She Called Me Baby (Karaoke Version) [Originally Performed By Charlie Rich]" : 'Charlie Rich'
    , "Super Kind of Woman (In the Style of Freddie Hart) [Karaoke Version]" : 'Freddie Hart'
    , "Got the All Overs for You (All Over Me)" : 'Freddie Hart'
    , "Easy Loving [In the Style of Freddie Hart] {Karaoke Lead Vocal Version}" : 'Freddie Hart'

}

# %%
# Run twice??
original_artist_to_tracks = artist_to_tracks.copy()
original_artist_to_years = artist_to_years.copy()

for spotify_artist, tracks in original_artist_to_tracks.items():
    # Switch all tracks under one artist to a preferred one
    if spotify_artist in spotify_artist_to_preferred_artist.keys():
        preferred_artist = spotify_artist_to_preferred_artist[spotify_artist]
        if preferred_artist not in artist_to_tracks.keys(): # dicts can't change size during iteration
            print(f'Adding {preferred_artist} with {tracks[0]}')
            artist_to_tracks[preferred_artist] = [tracks[0]]
        else:
            print(f'Adding {tracks[0]} to existing {preferred_artist}')
            artist_to_tracks[preferred_artist] += [tracks[0]]
            
        if len(tracks) > 1:
            for track in tracks[1:]:
                if (preferred_artist, track) in artist_to_tracks.items():
                    print('! Already there')
                else:
                    print(f'Adding {track} to existing {preferred_artist}')
                    artist_to_tracks[preferred_artist] += [track]
        
        print('Removing', spotify_artist, '\n')
        artist_to_tracks.pop(spotify_artist) # don't need the artist we moved away from
        
    
    # Switch the artist for specific tracks to other ones
    for track in tracks:
        if spotify_artist == 'Done Again':
            print(f'example spotify artist has tracks variable of {tracks}\n')
        
        if track == 'My Hang-Up Is You - Single (In the Style of Freddie Hart) [Performance Track with Demonstration Vocals]':
            print('example is a track!')
        
        if track in track_to_preferred_artist.keys():
                     
            print(track)
            preferred_artist = track_to_preferred_artist[track]
            if preferred_artist in artist_to_tracks.keys():
                print(f'Adding {track} to existing {preferred_artist}')
                artist_to_tracks[preferred_artist] += [track]
            else:
                print(f'Adding {track} to new {preferred_artist}')
                artist_to_tracks[preferred_artist] = [track]
            
            # TODO: not picking up all the Freddie Hart karaoke track.  Is it remove, or the loop?
            artist_to_tracks[spotify_artist].remove(track)

# del original_artist_to_tracks
# Out:
# Somewhere Tonight - Single (In the Style of Highway 101) [Performance Track with Demonstration Vocals]
# Adding Somewhere Tonight - Single (In the Style of Highway 101) [Performance Track with Demonstration Vocals] to existing Highway 101
# Bar Room Buddies (In the Style of Merle Haggard & Clint Eastwood) [Karaoke Version]
# Adding Bar Room Buddies (In the Style of Merle Haggard & Clint Eastwood) [Karaoke Version] to existing Merle Haggard
# Bar Room Buddies (In the Style of Merle Haggard & Clint Eastwood) [Karaoke Version]
# Adding Bar Room Buddies (In the Style of Merle Haggard & Clint Eastwood) [Karaoke Version] to existing Merle Haggard
# example spotify artist has tracks variable of ['My Hang-Up Is You - Single (In the Style of Freddie Hart) [Performance Track with Demonstration Vocals]']
#
# example is a track!
# My Hang-Up Is You - Single (In the Style of Freddie Hart) [Performance Track with Demonstration Vocals]
# ...

# %%
# Remove specific artists with songs (used for supporting bands without their own hits)
for to_ignore in ignorable_artists:
    artist_to_tracks.pop(to_ignore)
    print(to_ignore, 'popped')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-316-b9c60a19ac2b> in <module>
#       1 # Remove specific artists with songs (used for supporting bands without their own hits)
#       2 for to_ignore in ignorable_artists:
# ----> 3     artist_to_tracks.pop(to_ignore)
#       4     print(to_ignore, 'popped')
#
# KeyError: 'The Strangers'

# %%
artist_to_tracks['Highway 101']
# Out:
# ["Who's Lonely Now",
#  '(Do You Love Me) Just Say Yes',
#  'Cry, Cry, Cry',
#  'Somewhere Tonight - Single (In the Style of Highway 101) [Performance Track with Demonstration Vocals]']

# %%
artist_to_tracks['Done Again']
# Out:
# []

# %%
all_orig_tracks.index(
    'My Hang-Up Is You - Single (In the Style of Freddie Hart) [Performance Track with Demonstration Vocals]'
)
# Out:
# 1108

# %%
track_to_preferred_artist[
    'My Hang-Up Is You - Single (In the Style of Freddie Hart) [Performance Track with Demonstration Vocals]'
]
# Out:
# 'Freddie Hart'

# %%
(
    'My Hang-Up Is You - Single (In the Style of Freddie Hart) [Performance Track with Demonstration Vocals]'
    in list(track_to_preferred_artist.keys())
)
# Out:
# True

# %%
artist_to_tracks['Merle Haggard & The Strangers']
artist_to_tracks['Jack Blanchard']
artist_to_tracks['Merle Haggard']
artist_to_tracks['The Strangers'] # Expect KeyError
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-237-e9c1e4d7da88> in <module>
# ----> 1 artist_to_tracks['Merle Haggard & The Strangers']
#       2 artist_to_tracks['Jack Blanchard']
#       3 artist_to_tracks['Merle Haggard']
#       4 artist_to_tracks['The Strangers'] # Expect KeyError
#
# KeyError: 'Merle Haggard & The Strangers'

# %%
artist_to_num_tracks = {}
for artist, tracks in artist_to_tracks.items():
    artist_to_num_tracks[artist] = len(set(tracks)) # set to remove duplicates just in case

artist_to_num_tracks = {
    artist: num_tracks
    for artist, num_tracks
    in sorted(
        artist_to_num_tracks.items()
        , key = lambda ele: ele[1]
        , reverse = True
    )
}

# %%
artist_to_albums_of_tracks['George Strait']
# Out:
# {'Troubadour': '2008-01-01',
#  'It Just Comes Natural': '2006-01-01',
#  'Somewhere Down In Texas': '2005-01-01',
#  'Best Of (Deluxe Edition)': '2011-01-01',
#  'Carrying Your Love With Me': '1997-01-01',
#  'The Road Less Traveled': '2001-01-01',
#  "Father's Day": '2018-06-01',
#  'Always Never The Same': '1999-01-01',
#  'One Step At A Time': '1998-01-01',
#  'Blue Clear Sky': '1996-01-01',
#  'Strait Out Of The Box': '1995-09-12',
#  'Lead On': '1994-01-01',
#  'Easy Come Easy Go': '1993-01-01',
#  'Pure Country': '1992-01-01',
#  'Chill Of An Early Fall': '1991-01-01',
#  "Livin' It Up": '1990-01-01',
#  'Beyond The Blue Neon': '1989-01-01',
#  "If You Ain't Lovin', You Ain't Livin'": '1988-01-01',
#  'Ocean Front Property': '1987-01-01',
#  '#7': '1986-01-01',
#  'Something Special': '1985-01-01',
#  'Does Fort Worth Ever Cross Your Mind': '1984-01-01',
#  'Right Or Wrong': '1983-01-01',
#  'Strait From The Heart': '1982-01-01'}

# %%
for artist in artist_to_num_tracks.keys():
    print(
        artist
        , artist_to_num_tracks.get(artist)
    )
    pp(artist_to_albums_of_tracks.get(artist))
    print('\n')
# Out:
# George Strait 44
# {
#     "Troubadour": "2008-01-01",
#     "It Just Comes Natural": "2006-01-01",
#     "Somewhere Down In Texas": "2005-01-01",
#     "Best Of (Deluxe Edition)": "2011-01-01",
#     "Carrying Your Love With Me": "1997-01-01",
#     "The Road Less Traveled": "2001-01-01",
#     "Father's Day": "2018-06-01",
#     "Always Never The Same": "1999-01-01",
#     "One Step At A Time": "1998-01-01",
#     "Blue Clear Sky": "1996-01-01",
#     "Strait Out Of The Box": "1995-09-12",
#     "Lead On": "1994-01-01",
#     "Easy Come Easy Go": "1993-01-01",
#     "Pure Country": "1992-01-01",
#     "Chill Of An Early Fall": "1991-01-01",
#     "Livin' It Up": "1990-01-01",
#     "Beyond The Blue Neon": "1989-01-01",
#     "If You Ain't Lovin', You Ain't Livin'": "1988-01-01",
#     "Ocean Front Property": "1987-01-01",
#     "#7": "1986-01-01",
#     "Something Special": "1985-01-01",
#     "Does Fort Worth Ever Cross Your Mind": "1984-01-01",
# ...
